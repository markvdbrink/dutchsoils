# %% [markdown]
# # 2. Get data of a SoilProfile

# %%
import dutchsoils as ds

# %% [markdown]
# ## 2.0. Get soil profile

# %%
# Get soil profile
sp = ds.SoilProfile.from_bofekcluster(1008)

# %% [markdown]
# ## 2.1. Get all data (default)

# %%
sp.get_data_horizons()
# Out:
#    layernumber faohorizonnotation  ztop  zbottom staringseriesblock  \
# 0            1                Ahg  0.00     0.10                B17
# 1            2                Cwg  0.10     0.35                O13
# 2            3                 Cw  0.35     0.80                O17
# 3            4                BCb  0.80     0.95                O01
# 4            5                 Cu  0.95     1.20                O01
#
#    organicmattercontent  organicmattercontent10p  organicmattercontent90p  \
# 0                  20.0                     10.0                     30.0
# 1                   7.0                      5.0                     30.0
# 2                  75.0                     60.0                     90.0
# 3                   3.0                      1.0                      8.0
# 4                   0.4                      0.1                      3.0
#
#    acidity  acidity10p  ...  siltcontent  density wcres     wcsat  vgmalpha  \
# 0      5.0         4.5  ...           35    0.641  0.00  0.718626  0.019062
# 1      5.0         4.5  ...           35    1.044  0.01  0.573268  0.027854
# 2      5.0         4.7  ...           57    0.232  0.01  0.848635  0.011929
# 3      4.8         4.5  ...            6    1.545  0.01  0.365847  0.015987
# 4      4.8         4.5  ...            6    1.668  0.01  0.365847  0.015987
#
#     vgmnpar  vgmlambda    ksatfit                staringblockdescription  \
# 0  1.136658   0.000100   4.483735                            venige klei
# 1  1.079952  -6.091311   9.689291                        zeer zware klei
# 2  1.271536  -1.249300   3.402009              mesotroof en eutroof veen
# 3  2.162751   2.867967  22.322154  leemarm zeer fijn tot matig fijn zand
# 4  2.162751   2.867967  22.322154  leemarm zeer fijn tot matig fijn zand
#
#         staringblocklabel
# 0             venige klei
# 1              z.zw. klei
# 2       meso-eutroof veen
# 3  leemarm z.f.-m.f. zand
# 4  leemarm z.f.-m.f. zand
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 2.2. Get chemical data

# %%
sp.get_data_horizons(which="chemical")
# Out:
#    layernumber faohorizonnotation  ztop  zbottom  organicmattercontent  \
# 0            1                Ahg  0.00     0.10                  20.0
# 1            2                Cwg  0.10     0.35                   7.0
# 2            3                 Cw  0.35     0.80                  75.0
# 3            4                BCb  0.80     0.95                   3.0
# 4            5                 Cu  0.95     1.20                   0.4
#
#    organicmattercontent10p  organicmattercontent90p  acidity  acidity10p  \
# 0                     10.0                     30.0      5.0         4.5
# 1                      5.0                     30.0      5.0         4.5
# 2                     60.0                     90.0      5.0         4.7
# 3                      1.0                      8.0      4.8         4.5
# 4                      0.1                      3.0      4.8         4.5
#
#    acidity90p  cnratio   peattype  calciccontent  fedith
# 0         5.5       12        NaN            0.0     2.1
# 1         5.5       14        NaN            0.0     2.0
# 2         5.5       22  zeggeveen            0.0     1.4
# 3         5.2       22        NaN            0.0     0.4
# 4         5.2       22        NaN            0.0     0.3

# %% [markdown]
# ## 2.3. Get physical/textural data

# %%
sp.get_data_horizons(which="physical")
# Out:
#    layernumber faohorizonnotation  ztop  zbottom  loamcontent  loamcontent10p  \
# 0            1                Ahg  0.00     0.10           75              40
# 1            2                Cwg  0.10     0.35           90              70
# 2            3                 Cw  0.35     0.80           75              45
# 3            4                BCb  0.80     0.95            8               5
# 4            5                 Cu  0.95     1.20            8               5
#
#    loamcontent90p  lutitecontent  lutitecontent10p  lutitecontent90p  \
# 0              90             40                25                60
# 1             100             55                40                70
# 2              85             18                 6                30
# 3              20              2                 1                 4
# 4              20              2                 1                 4
#
#    sandmedian  sandmedian10p  sandmedian90p  siltcontent  density
# 0         140            110            170           35    0.641
# 1         110             90            130           35    1.044
# 2         125            110            140           57    0.232
# 3         160            140            180            6    1.545
# 4         160            140            180            6    1.668

# %% [markdown]
# ## 2.4. Get hydraulic data

# %%
sp.get_data_horizons(which="hydraulic")
# Out:
#    layernumber faohorizonnotation  ztop  zbottom staringseriesblock  wcres  \
# 0            1                Ahg  0.00     0.10                B17   0.00
# 1            2                Cwg  0.10     0.35                O13   0.01
# 2            3                 Cw  0.35     0.80                O17   0.01
# 3            4                BCb  0.80     0.95                O01   0.01
# 4            5                 Cu  0.95     1.20                O01   0.01
#
#       wcsat  vgmalpha   vgmnpar  vgmlambda    ksatfit  \
# 0  0.718626  0.019062  1.136658   0.000100   4.483735
# 1  0.573268  0.027854  1.079952  -6.091311   9.689291
# 2  0.848635  0.011929  1.271536  -1.249300   3.402009
# 3  0.365847  0.015987  2.162751   2.867967  22.322154
# 4  0.365847  0.015987  2.162751   2.867967  22.322154
#
#                  staringblockdescription       staringblocklabel
# 0                            venige klei             venige klei
# 1                        zeer zware klei              z.zw. klei
# 2              mesotroof en eutroof veen       meso-eutroof veen
# 3  leemarm zeer fijn tot matig fijn zand  leemarm z.f.-m.f. zand
# 4  leemarm zeer fijn tot matig fijn zand  leemarm z.f.-m.f. zand
