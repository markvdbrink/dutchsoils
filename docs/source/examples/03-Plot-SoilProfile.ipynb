# %% [markdown]
# # 3. Plot a SoilProfile

# %%
import dutchsoils as ds

# %% [markdown]
# ## 3.0. Get soil profile

# %%
sp = ds.SoilProfile.from_bofekcluster(1008)

# %% [markdown]
# ## 3.1. Plot profile

# %%
sp.plot()
